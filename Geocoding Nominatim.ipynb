# %%
from geopy.geocoders import Nominatim

# %%
locator = Nominatim(user_agent="myGeocoder")

# %%
location = locator.geocode("Freetown, Sierra Leone")
print("Latitude = {}, Longitude = {}".format(location.latitude, location.longitude))
# Out:
# Latitude = 8.479004, Longitude = -13.26795

# %%
location.raw
# Out:
# {'place_id': 279060928,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'node',
#  'osm_id': 27565056,
#  'lat': '8.479004',
#  'lon': '-13.26795',
#  'class': 'place',
#  'type': 'city',
#  'place_rank': 15,
#  'importance': 0.5992902034728199,
#  'addresstype': 'city',
#  'name': 'Freetown',
#  'display_name': 'Freetown, Western Area Urban, Western Area, Sierra Leone',
#  'boundingbox': ['8.3190040', '8.6390040', '-13.4279500', '-13.1079500']}

# %%
location.point
# Out:
# Point(8.479004, -13.26795, 0.0)

# %%
location.longitude
# Out:
# -13.26795

# %%
location.latitude
# Out:
# 8.479004

# %%
location.altitude
# Out:
# 0.0

# %%
location.address
# Out:
# 'Freetown, Western Area Urban, Western Area, Sierra Leone'
